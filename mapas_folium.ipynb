# %% [markdown]
# ###Guardar una copia en Drive

# %% [markdown]
# ###Instalar librería Folium

# %%
# !pip install folium

# %% [markdown]
# ###Hacer un mapa

# %%
import folium
m=folium.Map(location=[19.4978, -99.1269], zoom_start=11)
m

# %% [markdown]
# ###Colocar un marcador

# %%
import folium
m=folium.Map(location=[19.4978, -99.1269], zoom_start=11)
folium.Marker([19.4978, -99.1269], popup='Texto', tooltip='Clic').add_to(m)
m

# %% [markdown]
# ###Obtener geoJSON
#
# https://team.carto.com/u/andrew/tables/mexican_states/public?redirected=true

# %% [markdown]
# ###Instalar librería Geopandas

# %%
# !pip install geopandas

# %% [markdown]
# ###Sombrear un área

# %%
import pandas as pd
import geopandas

df=geopandas.read_file('mexican_states.geojson')
d1=df.iat[10,-1]

m=folium.Map(location=[26, -99.156], zoom_start=4.5)
folium.GeoJson(d1,name='geojson').add_to(m)
m

# %% [markdown]
# ###Colores
# https://en.wikipedia.org/wiki/X11_color_names

# %% [markdown]
# ###Sombrear dos áreas con distinto color

# %%
import pandas as pd
import geopandas

df=geopandas.read_file('mexican_states.geojson')
d1=df.iat[5,-1]
d2=df.iat[7,-1]

m=folium.Map(location=[26, -99.156], zoom_start=4.5)
folium.GeoJson(d1,name='geojson').add_to(m)

style2 = {'fillColor': '#8A2BE2', 'color': '#FF7F50'}
folium.GeoJson(d2,name='geojson',style_function=lambda x:style2).add_to(m)
m
#m.save('mapa.html') #Guardar mapa
